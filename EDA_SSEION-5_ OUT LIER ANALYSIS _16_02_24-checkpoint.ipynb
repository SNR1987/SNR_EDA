# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="D:\\nareshit\\omkar_python\\data_analysis\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# orange line is nothing bit median value
# black dots are all outliers

# %%
.. code-block:: none

          Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
                       |-----:-----|
       o      |--------|     :     |--------|    o  o
                       |-----:-----|
     flier             <----------->            fliers
                            IQR

# %%
# procedure to find the outlaiers
# calculate the q1,q2 and q3 , 
# calculate the range of  IQR(INTER QUARTAIL RANGE)=Q3-Q1
#find the upper bound : Q3+(1.5*IQR)
#Find the lower bound : Q1-(1.5*IQR)
#Find the out laiers  which are greater than upper bound , and less than the lower bound

# %%
#step-1
p_wage=visa_df["prevailing_wage"]
#step-2
Q1=np.quantile(p_wage,0.25)
Q2=np.quantile(p_wage,0.50)
Q3=np.quantile(p_wage,0.75)
#step-3
IQR=Q3-Q1
UB=Q3+(1.5*IQR)
LB=Q1-(1.5*IQR)
UP,LB
#step-4
con_1=visa_df["prevailing_wage"]>UB
con_2=visa_df["prevailing_wage"]<LB
res=visa_df[con_1 | con_2]
res
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
IQR=Q3-Q1
UB=Q3+(1.5*IQR)
LB=Q1-(1.5*IQR)
UP,LB
con_1=visa_df["prevailing_wage"]>UB
con_2=visa_df["prevailing_wage"]<LB

# %%
res=visa_df[con_1 | con_2]
res
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
def find_outliers(cols):
#step-1
    #step-2
    Q1=np.quantile(visa_df[cols],0.25)
    Q2=np.quantile(visa_df[cols],0.50)
    Q3=np.quantile(visa_df[cols],0.75)
    #step-3
    IQR=Q3-Q1
    UB=Q3+(1.5*IQR)
    LB=Q1-(1.5*IQR)
    UP,LB
    #step-4
    con_1=visa_df[cols]>UB
    con_2=visa_df[cols]<LB
    res_outliers=visa_df[con_1 | con_2]
    
    print(f"{cols} has {len(res_outliers)} outliers ")
    #print(res_outliers)
num_cols=visa_df.select_dtypes(exclude="object").columns
for cols in num_cols:
    find_outliers(cols)
# Out:
# no_of_employees has 1556 outliers
# yr_of_estab has 3260 outliers
# prevailing_wage has 427 outliers

# %%
#step-1
p_wage=visa_df["prevailing_wage"]
#step-2
Q1=np.quantile(p_wage,0.25)
Q2=np.quantile(p_wage,0.50)
Q3=np.quantile(p_wage,0.75)
#step-3
IQR=Q3-Q1
UB=Q3+(1.5*IQR)
LB=Q1-(1.5*IQR)
UP,LB
#step-4
con_1=visa_df["prevailing_wage"]>UB
con_2=visa_df["prevailing_wage"]<LB
res=visa_df[con_1 | con_2]
res
#non out liers data 
con_11=visa_df["prevailing_wage"]<UB
con_22=visa_df["prevailing_wage"]>LB
res_non_outliers=visa_df[con_11 & con_22]
res_non_outliers
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(res),len(res_non_outliers)
# Out:
# (427, 25053)

# %%
plt.subplot(2,2,1)
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.subplot(2,2,2)
plt.boxplot(res_non_outliers['prevailing_wage'],vert=False)
plt.subplot(2,2,3)
plt.hist(visa_df['prevailing_wage'],vert=False)
plt.subplot(2,2,4)
plt.hist(res_non_outliers['prevailing_wage'],vert=False)
plt.show()
