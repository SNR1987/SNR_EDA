# %%
#bi variate analysis

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="D:\\nareshit\\omkar_python\\data_analysis\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# categorival vs categorical 
# column 1= continent 
# column 2= case_status
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
#i want to know how many people got the visa out this fill numbers
con_1=visa_df["continent"]=="Asia"
con_2=visa_df["case_status"]=="Certified"
con_3=visa_df["case_status"]=="Denied"
certified_asia=con_1 & con_2
denied_asia=con_1 & con_3
len(visa_df[certified_asia]),len(visa_df[denied_asia])
# Out:
# (11012, 5849)

# %%
visa_df[certified_asia]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
con_1=visa_df["continent"]=="Asia"
con_2=visa_df["case_status"]=="Certified"
con_3=visa_df["case_status"]=="Denied"
certified_con=con_1 & con_2
denied_con=con_1 & con_3
len(visa_df[certified_con]),len(visa_df[denied_con])
